# %%
pip install -U spacy
# Out:
# Requirement already satisfied: spacy in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (3.4.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy) (4.64.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.28.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.10.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy) (0.10.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.0.10)
# Requirement already satisfied: packaging>=20.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy) (21.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy) (8.1.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.0.9)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.4.5)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.0.3)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy) (0.6.2)
# Requirement already satisfied: setuptools in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy) (63.2.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy) (0.4.2)
# Requirement already satisfied: jinja2 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.23.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.1.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.3)
# Requirement already satisfied: colorama in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from jinja2->spacy) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.1 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python -m spacy download pt_core_news_sm
# Out:
# Collecting pt-core-news-sm==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-3.4.0/pt_core_news_sm-3.4.0-py3-none-any.whl (13.0 MB)
#      --------------------------------------- 13.0/13.0 MB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from pt-core-news-sm==3.4.0) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (3.1.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (0.10.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (2.0.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (1.0.3)
# Requirement already satisfied: setuptools in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (63.2.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (1.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (21.3)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (0.6.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (0.4.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (3.0.10)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (3.3.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (1.23.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (4.64.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (8.1.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (3.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (2.4.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (2.28.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (1.10.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (4.4.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (0.7.9)
# Requirement already satisfied: colorama in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (0.4.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\arthu\appdata\local\programs\python\python310\lib\site-packages (from jinja2->spacy<3.5.0,>=3.4.0->pt-core-news-sm==3.4.0) (2.1.1)
# Installing collected packages: pt-core-news-sm
# Successfully installed pt-core-news-sm-3.4.0
# [+] Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# [notice] A new release of pip available: 22.2.1 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import json
import codecs
import time
import requests
import os
from IPython.display import clear_output

with open('pkmn_dict.json','r',encoding='utf-8') as f:
    pkmn_dict = json.load(f)

with open('tipo_pkmn.json','r',encoding='utf-8') as f:
    tipo_pkmn = json.load(f)
    
url_pokedex = ('https://pokemondb.net/pokedex/all')

def calculo_mult_tipos(tipo_pkmn,tipo_1,tipo_2):
    calc_vec_tipo_1 = np.zeros(len(tipo_pkmn),dtype =np.float32)
    calc_vec_tipo_2 = np.zeros(len(tipo_pkmn),dtype =np.float32)
    for idx, w in enumerate(tipo_pkmn):
        
        if w in pkmn_dict[tipo_1][0]:
          calc_vec_tipo_1[idx] = calc_vec_tipo_1[idx] - 1
        if w in pkmn_dict[tipo_1][2]:
          calc_vec_tipo_1[idx] = calc_vec_tipo_1[idx] + 1 
        if w in pkmn_dict[tipo_1][3]:
          calc_vec_tipo_1[idx] = calc_vec_tipo_1[idx] + 100

        if w in pkmn_dict[tipo_2][0]:
            calc_vec_tipo_2[idx] = calc_vec_tipo_2[idx] - 1
        if w in pkmn_dict[tipo_2][2]:
          calc_vec_tipo_2[idx] = calc_vec_tipo_2[idx] + 1
        if w in pkmn_dict[tipo_2][3]:
          calc_vec_tipo_2[idx] = calc_vec_tipo_2[idx] + 100

        calc_vec = np.add(calc_vec_tipo_1,calc_vec_tipo_2)
    return calc_vec

def call_api(nome_pkmn):
    resposta = requests.get(f'https://pokeapi.co/api/v2/pokemon/{nome_pkmn}')
    if resposta.status_code == 200:
        x = resposta.json()
        x = x['types']
        tipos = []
        for i in range(len(x)):
            tipos.append(x[i]['type']['name']) 
        return tipos
    else:
        return 'erro'

def norm_user_input(user_input):
    texto = user_input.lower()
    return user_input.lower()

# %%
contador = 0
while True:
    contador = contador + 1
    clear_output(wait=True)
    print('Bot: Bem vindo ao assistente de batalha Pokemon!')
    time.sleep(2)
    
    print('Bot: Digite o nome do pokemon que você está lutando contra')

    nome_pkmn = norm_user_input(input('User:'))

    tipos = call_api(nome_pkmn)

    if tipos == 'erro':
        url_pokedex = 'https://pokemondb.net/pokedex/all'
        print('Bot: Nao conheço esse pokemon')
        time.sleep(2)
        print(f'Bot: Clique nesse link para ver a pokedex e procurar pelo nome correto do pokemon: {url_pokedex}')
        time.sleep(15)
        clear_output(wait=True)
        break

    if len(tipos) > 1:
        tipo_1 = tipos[0]
        tipo_2 = tipos[1]

        neg = []
        efetivo_2x = []
        efetivo_4x = []
        imunidade = []

        func = calculo_mult_tipos(tipo_pkmn,tipo_1,tipo_2)

        for idx, w in enumerate(func):
            if w < 0 or w > 90:
                neg.extend([[tipo_pkmn[idx],w]])
        for x,y in neg:
            if y == -1:
                efetivo_2x.append(x)
            if y <= -2:
                efetivo_4x.append(x)
            if y > 90:
                imunidade.append(x)

        if len(efetivo_2x) > 1:
            time.sleep(2)
            tipos_2x = ', '.join(efetivo_2x)
            print(f'Bot: O pokemon toma super efetivo 2x dos tipos: {tipos_2x}')
        else:
            time.sleep(2)
            print(f'Bot: O pokemon toma super efetivo 2x do tipo: {efetivo_2x[0]}')

        if len(efetivo_4x) > 1:
            time.sleep(2)
            tipos_4x = ', '.join(efetivo_4x)
            print(f'Bot: O pokemon toma super efetivo 4x dos tipos: {tipos_4x}')
        elif len(efetivo_4x) == 1:
            time.sleep(2)
            print(f'Bot: O pokemon toma super efetivo 4x do tipo: {efetivo_4x[0]}')

        if len(imunidade) == 1:
            time.sleep(2)
            print(f'Bot: O pokemon é imune ao tipo: {imunidade[0]}')
        elif len(imunidade) > 1:
            time.sleep(2)
            imunidades = ', '.join(imunidade)
            print(f'Bot: O pokemon é imune aos tipos: {imunidades}')


    if len(tipos) == 1:
        tipo = tipos[0]
        melhores_tipo = ', '.join(pkmn_dict[tipo][0])
        imunidade = ', '.join(pkmn_dict[tipo][3])

        print(f'Bot: Tipos que dão super efetivo contra {tipo}: {melhores_tipo}')
        time.sleep(1)

        if imunidade != '':
            time.sleep(1)
            print(f'Bot: Tipos que {tipo} tem imunidade: {imunidade}')
    
    time.sleep(2)
    contador = contador + 1
    
    word=input('Bot: Digite "pare" para terminar o atendimento, caso queira repetir o processo digite qualquer coisa\nBot: O programa ira terminar automaticamente após 6 usos\nUser:')
    
    if word == 'pare' or contador > 6 :
        print('Bot: Obrigado por usar o Assistente de batalha :)')
        time.sleep(2)
        break
# Out:
# Bot: Bem vindo ao assistente de batalha Pokemon!
# Bot: Digite o nome do pokemon que você está lutando contra
# User:arthur
# Bot: Nao conheço esse pokemon
# Bot: Clique nesse link para ver a pokedex e procurar pelo nome correto do pokemon: https://pokemondb.net/pokedex/all
